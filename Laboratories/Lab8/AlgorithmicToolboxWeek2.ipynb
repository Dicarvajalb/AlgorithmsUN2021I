# %% [markdown]
# <a href="https://colab.research.google.com/github/Dicarvajalb/AlgorithmsUN2021I/blob/main/Laboratories/Lab8/AlgorithmicToolboxWeek2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Programming Assignment 2:Algorithmic Warm-up**

# %% [markdown]
# ##Fibonacci Number

# %%
# %%writefile 1_fibonacci.cpp
#
# #include <iostream>
# #include <cassert>
#
# int fibonacci_naive(int n) {
#     if (n <= 1)
#         return n;
#
#     return fibonacci_naive(n - 1) + fibonacci_naive(n - 2);
# }
#
# int fibonacci_fast(int n) {
#     // write your code here
#     int aux1 = 0;
#     int aux2 = 1;
#     if(n==0) return 0;
#     for(int i = 1; i<n ;i++){
#         aux2 += aux1;
#         aux1 = aux2 - aux1;
#     }
#     return aux2;
# }
#
# void test_solution() {
#     assert(fibonacci_fast(3) == 2);
#     assert(fibonacci_fast(10) == 55);
#     for (int n = 0; n < 20; ++n)
#         assert(fibonacci_fast(n) == fibonacci_naive(n));
# }
#
# int main() {
#     int n = 0;
#     std::cin >> n;
#
#     //std::cout << fibonacci_naive(n) << '\n';
#     //test_solution();
#     std::cout << fibonacci_fast(n) << '\n';
#     return 0;
# }
# Out:
# Overwriting 1_fibonacci.cpp

# %%
# !g++ 1_fibonacci.cpp -o executable
# !./executable
# Out:
# 10
# 55

# %% [markdown]
# ##Last Digit of a Large Fibonacci Number

# %%
# %%writefile 2_last_fibo.cpp
#
# #include <iostream>
#
# int get_fibonacci_last_digit_naive(int n) {
#     if (n <= 1)
#         return n;
#
#     int previous = 0;
#     int current  = 1;
#
#     for (int i = 0; i < n - 1; ++i) {
#         int tmp_previous = previous;
#         previous = current%10;
#         current = (tmp_previous + current)%10;
#     }
#
#     return current;
# }
#
# int main() {
#     int n;
#     std::cin >> n;
#     int c = get_fibonacci_last_digit_naive(n);
#     std::cout << c << '\n';
#     }
# Out:
# Overwriting 2_last_fibo.cpp

# %%
# !g++ 2_last_fibo.cpp -o executable
# !./executable
# Out:
# 331
# 9

# %% [markdown]
# ##Greatest Common Divisor

# %%
# %%writefile gcd.cpp
#
# #include <iostream>
#
# int gcd_naive(int a, int b) {
#   int a1 = a%b;
#
#   if (a1 == 0) return b;
#   else return gcd_naive(b,a1);
# }
#
# int main() {
#   int a, b;
#   std::cin >> a >> b;
#   std::cout << gcd_naive(a, b) << std::endl;
#   return 0;
# }
# Out:
# Writing gcd.cpp

# %%
# !g++ gcd.cpp -o executable
# !./executable
# Out:
# 28851538 1183019
# 17657

# %% [markdown]
# ##Least Common Multiple

# %%
# %%writefile lcm.cpp
#
# #include <iostream>
#
# long long lcm_naive(int a, int b) {
#   long long aux1 = 0;
#   for (long l = 1; aux1 <= (long long) a * b; l++)
#   {
#     aux1 = a*l;
#     if (aux1 % b == 0)
#       return aux1;
#   }
#   return (long long) a * b;
# }
#
# int main() {
#   int a, b;
#   std::cin >> a >> b;
#   std::cout << lcm_naive(a, b) << std::endl;
#   return 0;
# }
# Out:
# Overwriting lcm.cpp

# %%
# !g++ lcm.cpp -o executable
# !./executable
# Out:
# 761457 614573
# 467970912861

# %% [markdown]
# ##Fibonacci Number Again

# %%
# %%writefile 5_fibo.cpp
#
# #include <iostream>
# #include <string>
# using namespace std;
# int get_fibonacci_huge_naive(long long n, long long m) {
#     int period = 1;
#     if (n <= 1)
#         return period+1;
#
#     int previous = 0;
#     int current  = 1;
#
#     while(true) {
#         //cout<<previous<<endl;
#         long long tmp_previous = previous;
#         previous = current%m;
#         current = (tmp_previous + current)%m;
#
#         if(previous== 0 && current==1) return period;
#         else period ++;
#     }
#
#     return period;
# }
# long long fibonacci_fast(long long n, long long m) {
#     // write your code here
#     long long aux1 = 0;
#     long long aux2 = 1;
#     if(n==0) return 0;
#     for(int i = 1; i<n ;i++){
#         long long aux3 = aux2;
#         aux2 = (aux2 + aux1)%m;
#         aux1 = (aux3)%m;
#         //cout<<aux2<<endl;
#     }
#     return aux2%m;
# }
#
# int main() {
#     long long n, m;
#     cin >> n >> m;
#     long long equal = n%get_fibonacci_huge_naive(n, m);
#     //cout<<equal<<endl;
#     equal = fibonacci_fast(equal, m);
#     cout<<equal<<endl;
# }
# Out:
# Overwriting 5_fibo.cpp

# %%
# !g++ 5_fibo.cpp -o executable
# !./executable
# Out:
# 2816213588 239
# 151

# %% [markdown]
# ##Last Digit of the Sum of Fibonacci Numbers

# %%
# %%writefile 6_last_sum_fibo.cpp
#
# #include <iostream>
#
# int fibo_sum_mod(long long n, int m) {
#     if (n <= 1)
#         return n;
#     long long previous = 0;
#     long long current  = 1;
#     long long sum      = 1;
#
#     for (long long i = 0; i < n - 1; ++i) {
#         long long tmp_previous = previous;
#         previous = current%10;
#         current = (tmp_previous + current)%10;
#         sum = (sum + current)%10;
#     }
#     //std::cout<<sum<<std::endl;
#     return sum;
# }
# int get_period(long long m) {
#     int period = 1;
#     if (m <= 1)
#         return period-1;
#
#     int previous = 0;
#     int current  = 1;
#     int sum      = 1;
#     while(true) {
#         //cout<<previous<<endl;
#         long long tmp_previous = previous;
#         previous = current%m;
#         current = (tmp_previous + current)%m;
#
#         if(previous== 0 && current==1) return period;
#         else period ++;
#     }
#
#     return period;
# }
# int main() {
#
#     //int sum60 = fibo_sum_mod(period, mod);
#     long long n;
#    std::cin >> n;
#    // std::cout <<n<<std::endl;
#     long long equalN = n%60;
#     //std::cout <<equalN<<std::endl;
#     std::cout << fibo_sum_mod(equalN, 10);
# }
# Out:
# Overwriting 6_last_sum_fibo.cpp

# %%
# !g++ 6_last_sum_fibo.cpp -o executable
# !./executable
# Out:
# 3
# 4

# %% [markdown]
# ##Last Digit of the Sum of Fibonacci Numbers Again

# %%
# %%writefile 7_last_sum_fibo.cpp
#
# #include <iostream>
# #include <vector>
# using std::vector;
#
# long long fibo_sum_mod(long long n, int m) {
#     if(n == -1)
#         return 0;
#     if (n <= 1)
#         return n;
#     long long previous = 0;
#     long long current  = 1;
#     long long sum      = 1;
#
#     for (long long i = 0; i < n - 1; ++i) {
#         long long tmp_previous = previous;
#         previous = current%10;
#         current = (tmp_previous + current)%10;
#         sum = (sum + current);
#         //std::cout<<sum<<std::endl;
#     }
#
#     return sum;
#
# }
# int main() {
#     long long from, to;
#     std::cin >> from >> to;
#     to = (to)%60;
#     from = (from-1)%60;
#
#     long long resultTo = fibo_sum_mod(to, 10);
#     long long resultFrom = fibo_sum_mod(from, 10);
#     //std::cout<<resultFrom<<std::endl;
#     //std::cout<<resultTo<<std::endl;
#     int result = (resultTo-resultFrom)%10;
#     if(result<0) result =(10 +result)%10;
#     std::cout<<result<<std::endl;
# }
# Out:
# Overwriting 7_last_sum_fibo.cpp

# %%
# !g++ 7_last_sum_fibo.cpp -o executable
# !./executable
# Out:
# 10 200
# 2

# %% [markdown]
# ##Last Digit of the Sum of Squares of Fibonacci Numbers

# %%
# %%writefile 8_last_sum_fibo.cpp
# #include <iostream>
#
# using namespace std;
# int fibo_func(int n, int m){
#
#     if(n<=1) return n%10;
#     int previous = 0;
#     int current = 1;
#
#     for(int i = 0; i<n-1; i++){
#         int aux = previous;
#         previous = current%10;
#         current = (aux + current)%10;
#     }
#
#     return current;
# }
#
# int main(){
#     int n;
#     cin>>n;
#     int n1 = fibo_func(n%60,10);
#     int n2 = fibo_func((n-1)%60,10);
#     int total = (n1*n1 + n1*n2)%10;
#     cout<<total<<endl;
# }
# Out:
# Overwriting 8_last_sum_fibo.cpp

# %%
# !g++ 8_last_sum_fibo.cpp -o executable
# !./executable
# Out:
# 73
# 1

# %% [markdown]
# ![Captura de Pantalla 2021-07-14 a la(s) 12.40.27 p. m..png](data:image/png;base64,...)
